# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv('../data/train.csv')

# %%
user_df = train_df.groupby('user_id')

# %%
user_df.count()['row_id'].hist(bins=50)

# %%
user_df.count()['row_id'].min()
# Out:
# 1

# %%
user_df.count()['row_id'].max()
# Out:
# 17917

# %%
user_df.count()['row_id'].median()
# Out:
# 41.0

# %%
user_df.count()['row_id'].mean()
# Out:
# 257.1542971528441
